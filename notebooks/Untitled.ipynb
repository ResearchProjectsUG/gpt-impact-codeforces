# %%
import pandas as pd

# %%
cf_data = pd.read_csv("https://raw.githubusercontent.com/ResearchProjectsUG/gpt-impact-codeforces/main/data/codeforces-round-943-div-3/filtered_submissions_by_relative_time.csv")

# %%
cf_data
# Out:
#        submission_id  contest_id  creation_time_seconds  \
# 0          259134226        1968             1714661216
# 1          259145894        1968             1714661614
# 2          259152791        1968             1714661871
# 3          259184107        1968             1714663514
# 4          259207788        1968             1714665328
# ...              ...         ...                    ...
# 94684      259169789        1968             1714662663
# 94685      259191025        1968             1714663994
# 94686      259204557        1968             1714665066
# 94687      259239841        1968             1714668519
# 94688      259245799        1968             1714669122
#
#        relative_time_seconds problem_index author_handle participation_type  \
# 0                        116             A     --ALPHA--         CONTESTANT
# 1                        514             B     --ALPHA--         CONTESTANT
# 2                        771             B     --ALPHA--         CONTESTANT
# 3                       2414             C     --ALPHA--         CONTESTANT
# 4                       4228             D     --ALPHA--         CONTESTANT
# ...                      ...           ...           ...                ...
# 94684                   1563             C        zzzpLu         CONTESTANT
# 94685                   2894             D        zzzpLu         CONTESTANT
# 94686                   3966             E        zzzpLu         CONTESTANT
# 94687                   7419            G1        zzzpLu         CONTESTANT
# 94688                   8022            G1        zzzpLu         CONTESTANT
#
#       programming_language              verdict test_set  passed_test_count  \
# 0         C++17 (GCC 7-32)                   OK    TESTS                  6
# 1         C++17 (GCC 7-32)         WRONG_ANSWER    TESTS                  1
# 2         C++17 (GCC 7-32)                   OK    TESTS                 12
# 3         C++17 (GCC 7-32)                   OK    TESTS                 15
# 4         C++17 (GCC 7-32)                   OK    TESTS                 14
# ...                    ...                  ...      ...                ...
# 94684            PyPy 3-64                   OK    TESTS                 15
# 94685            PyPy 3-64                   OK    TESTS                 14
# 94686            PyPy 3-64                   OK    TESTS                 13
# 94687            PyPy 3-64  TIME_LIMIT_EXCEEDED    TESTS                 10
# 94688            PyPy 3-64  TIME_LIMIT_EXCEEDED    TESTS                 16
#
#        time_consumed_milliseconds  memory_consumed_bytes
# 0                              46                      0
# 1                              61                      0
# 2                              77                      0
# 3                             124                      0
# 4                             202               15667200
# ...                           ...                    ...
# 94684                         186                9932800
# 94685                         280               33894400
# 94686                         140                8396800
# 94687                        2000                7577600
# 94688                        2000                6553600
#
# [94689 rows x 13 columns]
